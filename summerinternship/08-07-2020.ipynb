# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = plt.imread("dg1.jpg")
print(img.shape)
# Out:
# (168, 300, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0],cmap='Blues')

# %%
plt.imshow(img[:,:150,:])

# %%
img1 = plt.imread("color.jpg")
print(img1.shape)
# Out:
# (168, 300, 3)

# %%
plt.imshow(img1)

# %%
plt.imshow(img1[:,:,0],cmap='gray')

# %%
plt.imshow(img1[:,:150,:])
